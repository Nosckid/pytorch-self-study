# %% [markdown]
# <a href="https://colab.research.google.com/github/Nosckid/pytorch-self-study/blob/main/01_PyTorch_Workflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PyTorch Workflow
#
# Let's explore an example PyTorch end-to-end workflow.
#
# Resources:
# *Book version of the course* - https://www.learnpytorch.io/01_pytorch_workflow/

# %%
what_were_covering ={
    1: "Data (prepare and load)",
    2: "Build model",
    3: "Fitting the model to data (training)",
    4: "Making predictions and evaluating a model (inference)",
    5: "Saving and loading a model",
    6: "Putting it all together"
}

what_were_covering
# Out:
# {1: 'Data (prepare and load)',
#  2: 'Build model',
#  3: 'Fitting the model to data (training)',
#  4: 'Making predictions and evaluating a model (inference)',
#  5: 'Saving and loading a model',
#  6: 'Putting it all together'}

# %% [markdown]
# ## 1 - Data (Preparing and Loading)
#
# Data can be almost anything in machine learning.
#
# It (machine learning) is a game of two parts:
#
# 1. Get data into a numerical representation.
# 2. Build a model to learn patterns in that numerical representation.
#
# To showcase this, let's create some *known* data using the linear regression formula. We'll use the formula to make a straight line with *known* **parameters**

# %% [markdown]
# ## 2. Build model
#
# What our model does:
# * Start with random values (weight & bias)
# * Look at training data and adjust the random values to better represent (or get closer to) the ideal values (the weight & bias values we used to create the data).
#
# How does it do so?
#
# Through two main algorithms:
# 1. Gradient descent
# 2. Backpropagation
